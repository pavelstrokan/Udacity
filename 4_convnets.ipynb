# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = '../../notMNIST.pickle'

with open(pickle_file, 'rb') as f:
    save = pickle.load(f)
    
    train_dataset = save['train_dataset']
    train_labels = save['train_labels']
    
    valid_dataset = save['valid_dataset']
    valid_labels = save['valid_labels']
    
    test_dataset = save['test_dataset']
    test_labels = save['test_labels']
    
    del save  # hint to help gc free up memory
    print('Training set', train_dataset.shape, train_labels.shape)
    print('Validation set', valid_dataset.shape, valid_labels.shape)
    print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
    dataset = dataset.reshape((-1, image_size, image_size, num_channels)).astype(np.float32)
    labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
    return dataset, labels

train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)

print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
    return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1)) \
            / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 1024

graph = tf.Graph()

with graph.as_default():

    # Input data.
    train = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    
    valid = tf.constant(valid_dataset)
    test = tf.constant(test_dataset)

    # Variables.
    w1 = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
    b1 = tf.Variable(tf.zeros([depth]))
    
    w2 = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
    b2 = tf.Variable(tf.constant(1.0, shape=[depth]))
    
    w3 = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    b3 = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    
    w4 = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
    b4 = tf.Variable(tf.constant(1.0, shape=[num_labels]))

    # Model.
    def model(data):
        conv = tf.nn.conv2d(data, w1, [1, 2, 2, 1], padding='SAME') + b1
        hidden = tf.nn.relu(conv)
        
        conv = tf.nn.conv2d(hidden, w2, [1, 2, 2, 1], padding='SAME') + b2
        hidden = tf.nn.relu(conv)
        
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        
        hidden = tf.nn.xw_plus_b(reshape, w3, b3)
        hidden = tf.nn.relu(hidden)
        
        return tf.nn.xw_plus_b(hidden, w4, b4)

    # Training computation.
    logits = model(train)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=labels, logits=logits))

    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(valid))
    test_prediction = tf.nn.softmax(model(test))

# %%
nb_steps = 1001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(nb_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {train : batch_data, labels : batch_labels}
        _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
    print('Validation accuracy: %.1f%%' % accuracy(
            valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 5.044826
# Minibatch accuracy: 12.5%
# Minibatch loss at step 50: 2.257859
# Minibatch accuracy: 31.2%
# Minibatch loss at step 100: 2.061034
# Minibatch accuracy: 18.8%
# Minibatch loss at step 150: 1.267842
# Minibatch accuracy: 62.5%
# Minibatch loss at step 200: 0.890392
# Minibatch accuracy: 68.8%
# Minibatch loss at step 250: 0.719255
# Minibatch accuracy: 81.2%
# Minibatch loss at step 300: 0.549546
# Minibatch accuracy: 87.5%
# Minibatch loss at step 350: 0.719501
# Minibatch accuracy: 75.0%
# Minibatch loss at step 400: 0.470098
# Minibatch accuracy: 87.5%
# Minibatch loss at step 450: 0.728643
# Minibatch accuracy: 81.2%
# Minibatch loss at step 500: 0.583343
# Minibatch accuracy: 75.0%
# Minibatch loss at step 550: 0.446994
# Minibatch accuracy: 81.2%
# Minibatch loss at step 600: 0.543558
# Minibatch accuracy: 81.2%
# Minibatch loss at step 650: 0.702579
# Minibatch accuracy: 75.0%
# Minibatch loss at step 700: 0.950412
# Minibatch accuracy: 68.8%
# Minibatch loss at step 750: 0.737710
# Minibatch accuracy: 75.0%
# Minibatch loss at step 800: 0.278079
# Minibatch accuracy: 87.5%
# Minibatch loss at step 850: 0.585507
# Minibatch accuracy: 75.0%
# Minibatch loss at step 900: 0.381098
# Minibatch accuracy: 81.2%
# Minibatch loss at step 950: 0.132202
# Minibatch accuracy: 93.8%
# Minibatch loss at step 1000: 0.379329
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.8%
# Test accuracy: 87.5%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

    # Input data.
    train = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    
    valid = tf.constant(valid_dataset)
    test = tf.constant(test_dataset)

    # Variables.
    w1 = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
    b1 = tf.Variable(tf.zeros([depth]))
    
    w2 = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
    b2 = tf.Variable(tf.constant(1.0, shape=[depth]))
    
    w3 = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
    b3 = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    
    w4 = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
    b4 = tf.Variable(tf.constant(1.0, shape=[num_labels]))

    # Model.
    def model(data):
        conv = tf.nn.conv2d(data, w1, [1, 1, 1, 1], padding='SAME') + b1
        hidden = tf.nn.relu(conv)
        maxpool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        
        conv = tf.nn.conv2d(maxpool, w2, [1, 1, 1, 1], padding='SAME') + b2
        hidden = tf.nn.relu(conv)
        maxpool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        
        shape = maxpool.get_shape().as_list()
        reshape = tf.reshape(maxpool, [shape[0], shape[1] * shape[2] * shape[3]])
        
        hidden = tf.nn.xw_plus_b(reshape, w3, b3)
        hidden = tf.nn.relu(hidden)
        
        return tf.nn.xw_plus_b(hidden, w4, b4)

    # Training computation.
    logits = model(train)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=labels, logits=logits))

    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(valid))
    test_prediction = tf.nn.softmax(model(test))

# %%
nb_steps = 1001
with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(nb_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {train : batch_data, labels : batch_labels}
        _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
    print('Validation accuracy: %.1f%%' % accuracy(
            valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.178649
# Minibatch accuracy: 6.2%
# Minibatch loss at step 50: 2.189816
# Minibatch accuracy: 6.2%
# Minibatch loss at step 100: 1.224128
# Minibatch accuracy: 56.2%
# Minibatch loss at step 150: 1.375121
# Minibatch accuracy: 62.5%
# Minibatch loss at step 200: 0.750853
# Minibatch accuracy: 75.0%
# Minibatch loss at step 250: 0.603216
# Minibatch accuracy: 81.2%
# Minibatch loss at step 300: 0.711165
# Minibatch accuracy: 81.2%
# Minibatch loss at step 350: 0.956233
# Minibatch accuracy: 75.0%
# Minibatch loss at step 400: 0.539745
# Minibatch accuracy: 87.5%
# Minibatch loss at step 450: 0.989764
# Minibatch accuracy: 68.8%
# Minibatch loss at step 500: 0.467473
# Minibatch accuracy: 81.2%
# Minibatch loss at step 550: 0.420324
# Minibatch accuracy: 87.5%
# Minibatch loss at step 600: 0.609977
# Minibatch accuracy: 81.2%
# Minibatch loss at step 650: 0.727440
# Minibatch accuracy: 81.2%
# Minibatch loss at step 700: 0.924767
# Minibatch accuracy: 68.8%
# Minibatch loss at step 750: 0.714200
# Minibatch accuracy: 75.0%
# Minibatch loss at step 800: 0.241863
# Minibatch accuracy: 93.8%
# Minibatch loss at step 850: 0.572979
# Minibatch accuracy: 87.5%
# Minibatch loss at step 900: 0.134548
# Minibatch accuracy: 100.0%
# Minibatch loss at step 950: 0.081498
# Minibatch accuracy: 100.0%
# Minibatch loss at step 1000: 0.336973
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.6%
# Test accuracy: 88.8%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 32
num_hidden = 1024

graph = tf.Graph()

with graph.as_default():

    # Input data.
    train = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    
    valid = tf.constant(valid_dataset)
    test = tf.constant(test_dataset)

    # Variables.
    w1 = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
    b1 = tf.Variable(tf.zeros([depth]))
    
    w2 = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth * 2], stddev=0.1))
    b2 = tf.Variable(tf.constant(1.0, shape=[depth * 2]))
    
    w3 = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth * 2, num_hidden], stddev=0.1))
    b3 = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    
    w4 = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
    b4 = tf.Variable(tf.constant(1.0, shape=[num_labels]))
    
    keep_prob = tf.placeholder(tf.float32, shape=[])

    # Model.
    def model(data):
        conv = tf.nn.conv2d(data, w1, [1, 1, 1, 1], padding='SAME') + b1
        hidden = tf.nn.relu(conv)
        maxpool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        
        conv = tf.nn.conv2d(maxpool, w2, [1, 1, 1, 1], padding='SAME') + b2
        hidden = tf.nn.relu(conv)
        maxpool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        
        shape = maxpool.get_shape().as_list()
        reshape = tf.reshape(maxpool, [shape[0], shape[1] * shape[2] * shape[3]])
        
        hidden = tf.nn.xw_plus_b(reshape, w3, b3)
        hidden = tf.nn.relu(hidden)
        dropout = tf.nn.dropout(hidden, keep_prob)
        
        hidden = tf.nn.xw_plus_b(dropout, w4, b4)
        
        return hidden#
    

    # Training computation.
    logits = model(train)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=labels, logits=logits))

    # Optimizer.
    global_step = tf.Variable(0)  # count the number of steps taken.
    learning_rate = tf.train.exponential_decay(1e-4, global_step, 500, 0.96)
    optimizer = tf.train.AdamOptimizer(learning_rate).minimize(loss, global_step=global_step)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(valid))
    test_prediction = tf.nn.softmax(model(test))

# %%
nb_steps = 20001
with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(nb_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {train : batch_data, labels : batch_labels, keep_prob: 0.5}
        _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
    print('Validation accuracy: %.1f%%' % accuracy(
            valid_prediction.eval({keep_prob: 1.0}), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval({keep_prob: 1.0}), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 24.463163
# Minibatch accuracy: 12.5%
# Minibatch loss at step 50: 13.132477
# Minibatch accuracy: 18.8%
# Minibatch loss at step 100: 6.159635
# Minibatch accuracy: 18.8%
# Minibatch loss at step 150: 6.755270
# Minibatch accuracy: 31.2%
# Minibatch loss at step 200: 2.322510
# Minibatch accuracy: 50.0%
# Minibatch loss at step 250: 1.775133
# Minibatch accuracy: 56.2%
# Minibatch loss at step 300: 1.186511
# Minibatch accuracy: 50.0%
# Minibatch loss at step 350: 1.340028
# Minibatch accuracy: 68.8%
# Minibatch loss at step 400: 0.745281
# Minibatch accuracy: 81.2%
# Minibatch loss at step 450: 1.324034
# Minibatch accuracy: 56.2%
# Minibatch loss at step 500: 0.855545
# Minibatch accuracy: 68.8%
# Minibatch loss at step 550: 1.006528
# Minibatch accuracy: 81.2%
# Minibatch loss at step 600: 0.957653
# Minibatch accuracy: 81.2%
# Minibatch loss at step 650: 0.968413
# Minibatch accuracy: 68.8%
# Minibatch loss at step 700: 1.202350
# Minibatch accuracy: 62.5%
# Minibatch loss at step 750: 1.000320
# Minibatch accuracy: 68.8%
# Minibatch loss at step 800: 0.824890
# Minibatch accuracy: 81.2%
# Minibatch loss at step 850: 0.812452
# Minibatch accuracy: 81.2%
# Minibatch loss at step 900: 0.989267
# Minibatch accuracy: 68.8%
# Minibatch loss at step 950: 0.501616
# Minibatch accuracy: 81.2%
# Minibatch loss at step 1000: 0.559468
# Minibatch accuracy: 75.0%
# Minibatch loss at step 1050: 0.872860
# Minibatch accuracy: 75.0%
# Minibatch loss at step 1100: 0.873281
# Minibatch accuracy: 68.8%
# Minibatch loss at step 1150: 1.006799
# Minibatch accuracy: 75.0%
# Minibatch loss at step 1200: 1.239193
# Minibatch accuracy: 62.5%
# Minibatch loss at step 1250: 0.812236
# Minibatch accuracy: 81.2%
# Minibatch loss at step 1300: 1.339614
# Minibatch accuracy: 62.5%
# Minibatch loss at step 1350: 0.672858
# Minibatch accuracy: 81.2%
# Minibatch loss at step 1400: 0.779622
# Minibatch accuracy: 75.0%
# Minibatch loss at step 1450: 0.265315
# Minibatch accuracy: 93.8%
# Minibatch loss at step 1500: 0.219747
# Minibatch accuracy: 93.8%
# Minibatch loss at step 1550: 1.723926
# Minibatch accuracy: 56.2%
# Minibatch loss at step 1600: 0.899870
# Minibatch accuracy: 75.0%
# Minibatch loss at step 1650: 1.629458
# Minibatch accuracy: 43.8%
# Minibatch loss at step 1700: 0.893861
# Minibatch accuracy: 75.0%
# Minibatch loss at step 1750: 0.313679
# Minibatch accuracy: 87.5%
# Minibatch loss at step 1800: 1.017799
# Minibatch accuracy: 75.0%
# Minibatch loss at step 1850: 0.387653
# Minibatch accuracy: 87.5%
# Minibatch loss at step 1900: 1.069767
# Minibatch accuracy: 68.8%
# Minibatch loss at step 1950: 0.509964
# Minibatch accuracy: 93.8%
# Minibatch loss at step 2000: 0.824968
# Minibatch accuracy: 75.0%
# Minibatch loss at step 2050: 0.921301
# Minibatch accuracy: 75.0%
# Minibatch loss at step 2100: 1.312501
# Minibatch accuracy: 68.8%
# Minibatch loss at step 2150: 1.201576
# Minibatch accuracy: 68.8%
# Minibatch loss at step 2200: 0.784458
# Minibatch accuracy: 68.8%
# Minibatch loss at step 2250: 1.234588
# Minibatch accuracy: 56.2%
# Minibatch loss at step 2300: 0.383993
# Minibatch accuracy: 87.5%
# Minibatch loss at step 2350: 0.365476
# Minibatch accuracy: 87.5%
# Minibatch loss at step 2400: 1.029360
# Minibatch accuracy: 68.8%
# Minibatch loss at step 2450: 1.060502
# Minibatch accuracy: 75.0%
# Minibatch loss at step 2500: 0.775578
# Minibatch accuracy: 81.2%
# Minibatch loss at step 2550: 1.700161
# Minibatch accuracy: 68.8%
# Minibatch loss at step 2600: 0.615570
# Minibatch accuracy: 81.2%
# Minibatch loss at step 2650: 1.741557
# Minibatch accuracy: 62.5%
# Minibatch loss at step 2700: 1.040248
# Minibatch accuracy: 68.8%
# Minibatch loss at step 2750: 0.563722
# Minibatch accuracy: 93.8%
# Minibatch loss at step 2800: 0.567005
# Minibatch accuracy: 87.5%
# Minibatch loss at step 2850: 0.524758
# Minibatch accuracy: 81.2%
# Minibatch loss at step 2900: 0.572562
# Minibatch accuracy: 81.2%
# Minibatch loss at step 2950: 1.160342
# Minibatch accuracy: 62.5%
# Minibatch loss at step 3000: 0.619920
# Minibatch accuracy: 75.0%
# Minibatch loss at step 3050: 0.340449
# Minibatch accuracy: 93.8%
# Minibatch loss at step 3100: 0.563040
# Minibatch accuracy: 81.2%
# Minibatch loss at step 3150: 0.650108
# Minibatch accuracy: 81.2%
# Minibatch loss at step 3200: 0.726265
# Minibatch accuracy: 87.5%
# Minibatch loss at step 3250: 0.545003
# Minibatch accuracy: 81.2%
# Minibatch loss at step 3300: 0.375164
# Minibatch accuracy: 87.5%
# Minibatch loss at step 3350: 0.330478
# Minibatch accuracy: 87.5%
# Minibatch loss at step 3400: 0.458589
# Minibatch accuracy: 87.5%
# Minibatch loss at step 3450: 0.438823
# Minibatch accuracy: 93.8%
# Minibatch loss at step 3500: 0.680424
# Minibatch accuracy: 81.2%
# Minibatch loss at step 3550: 0.731596
# Minibatch accuracy: 62.5%
# Minibatch loss at step 3600: 0.566282
# Minibatch accuracy: 75.0%
# Minibatch loss at step 3650: 0.832417
# Minibatch accuracy: 75.0%
# Minibatch loss at step 3700: 1.076246
# Minibatch accuracy: 68.8%
# Minibatch loss at step 3750: 0.409886
# Minibatch accuracy: 93.8%
# Minibatch loss at step 3800: 0.553116
# Minibatch accuracy: 81.2%
# Minibatch loss at step 3850: 0.621183
# Minibatch accuracy: 81.2%
# Minibatch loss at step 3900: 0.445146
# Minibatch accuracy: 81.2%
# Minibatch loss at step 3950: 0.408845
# Minibatch accuracy: 93.8%
# Minibatch loss at step 4000: 0.504857
# Minibatch accuracy: 87.5%
# Minibatch loss at step 4050: 0.902777
# Minibatch accuracy: 75.0%
# Minibatch loss at step 4100: 1.109925
# Minibatch accuracy: 81.2%
# Minibatch loss at step 4150: 0.983298
# Minibatch accuracy: 68.8%
# Minibatch loss at step 4200: 0.150775
# Minibatch accuracy: 100.0%
# Minibatch loss at step 4250: 1.153350
# Minibatch accuracy: 68.8%
# Minibatch loss at step 4300: 0.431372
# Minibatch accuracy: 87.5%
# Minibatch loss at step 4350: 0.590357
# Minibatch accuracy: 87.5%
# Minibatch loss at step 4400: 0.812063
# Minibatch accuracy: 68.8%
# Minibatch loss at step 4450: 1.227686
# Minibatch accuracy: 62.5%
# Minibatch loss at step 4500: 0.431884
# Minibatch accuracy: 87.5%
# Minibatch loss at step 4550: 0.403093
# Minibatch accuracy: 87.5%
# Minibatch loss at step 4600: 1.031763
# Minibatch accuracy: 68.8%
# Minibatch loss at step 4650: 0.485857
# Minibatch accuracy: 93.8%
# Minibatch loss at step 4700: 0.862572
# Minibatch accuracy: 68.8%
# Minibatch loss at step 4750: 0.239352
# Minibatch accuracy: 87.5%
# Minibatch loss at step 4800: 1.178976
# Minibatch accuracy: 68.8%
# Minibatch loss at step 4850: 0.545485
# Minibatch accuracy: 81.2%
# Minibatch loss at step 4900: 0.486660
# Minibatch accuracy: 81.2%
# Minibatch loss at step 4950: 0.795399
# Minibatch accuracy: 75.0%
# Minibatch loss at step 5000: 0.857819
# Minibatch accuracy: 75.0%
# Minibatch loss at step 5050: 0.244220
# Minibatch accuracy: 93.8%
# Minibatch loss at step 5100: 0.631170
# Minibatch accuracy: 75.0%
# Minibatch loss at step 5150: 0.633628
# Minibatch accuracy: 81.2%
# Minibatch loss at step 5200: 0.886097
# Minibatch accuracy: 68.8%
# Minibatch loss at step 5250: 0.768341
# Minibatch accuracy: 75.0%
# Minibatch loss at step 5300: 0.480999
# Minibatch accuracy: 87.5%
# Minibatch loss at step 5350: 0.755665
# Minibatch accuracy: 81.2%
# Minibatch loss at step 5400: 0.462006
# Minibatch accuracy: 87.5%
# Minibatch loss at step 5450: 0.468572
# Minibatch accuracy: 81.2%
# Minibatch loss at step 5500: 0.580970
# Minibatch accuracy: 75.0%
# Minibatch loss at step 5550: 0.418724
# Minibatch accuracy: 87.5%
# Minibatch loss at step 5600: 0.781985
# Minibatch accuracy: 75.0%
# Minibatch loss at step 5650: 0.941723
# Minibatch accuracy: 81.2%
# Minibatch loss at step 5700: 0.776199
# Minibatch accuracy: 75.0%
# Minibatch loss at step 5750: 0.542074
# Minibatch accuracy: 87.5%
# Minibatch loss at step 5800: 0.706236
# Minibatch accuracy: 87.5%
# Minibatch loss at step 5850: 1.103873
# Minibatch accuracy: 68.8%
# Minibatch loss at step 5900: 0.485063
# Minibatch accuracy: 87.5%
# Minibatch loss at step 5950: 0.234699
# Minibatch accuracy: 93.8%
# Minibatch loss at step 6000: 0.395370
# Minibatch accuracy: 87.5%
# Minibatch loss at step 6050: 1.327265
# Minibatch accuracy: 75.0%
# Minibatch loss at step 6100: 0.568054
# Minibatch accuracy: 87.5%
# Minibatch loss at step 6150: 0.493090
# Minibatch accuracy: 87.5%
# Minibatch loss at step 6200: 0.874011
# Minibatch accuracy: 75.0%
# Minibatch loss at step 6250: 0.342735
# Minibatch accuracy: 87.5%
# Minibatch loss at step 6300: 1.120446
# Minibatch accuracy: 62.5%
# Minibatch loss at step 6350: 0.715759
# Minibatch accuracy: 68.8%
# Minibatch loss at step 6400: 1.015025
# Minibatch accuracy: 62.5%
# Minibatch loss at step 6450: 0.551584
# Minibatch accuracy: 81.2%
# Minibatch loss at step 6500: 1.154112
# Minibatch accuracy: 62.5%
# Minibatch loss at step 6550: 0.769454
# Minibatch accuracy: 75.0%
# Minibatch loss at step 6600: 0.489729
# Minibatch accuracy: 81.2%
# Minibatch loss at step 6650: 0.677721
# Minibatch accuracy: 87.5%
# Minibatch loss at step 6700: 0.333930
# Minibatch accuracy: 87.5%
# Minibatch loss at step 6750: 1.487664
# Minibatch accuracy: 75.0%
# Minibatch loss at step 6800: 0.245672
# Minibatch accuracy: 93.8%
# Minibatch loss at step 6850: 1.171322
# Minibatch accuracy: 81.2%
# Minibatch loss at step 6900: 0.783109
# Minibatch accuracy: 68.8%
# Minibatch loss at step 6950: 0.254762
# Minibatch accuracy: 93.8%
# Minibatch loss at step 7000: 0.383523
# Minibatch accuracy: 93.8%
# Minibatch loss at step 7050: 0.832189
# Minibatch accuracy: 62.5%
# Minibatch loss at step 7100: 0.775929
# Minibatch accuracy: 75.0%
# Minibatch loss at step 7150: 0.672980
# Minibatch accuracy: 81.2%
# Minibatch loss at step 7200: 0.446890
# Minibatch accuracy: 87.5%
# Minibatch loss at step 7250: 0.479625
# Minibatch accuracy: 81.2%
# Minibatch loss at step 7300: 0.474567
# Minibatch accuracy: 93.8%
# Minibatch loss at step 7350: 0.613460
# Minibatch accuracy: 75.0%
# Minibatch loss at step 7400: 0.630333
# Minibatch accuracy: 81.2%
# Minibatch loss at step 7450: 0.963884
# Minibatch accuracy: 62.5%
# Minibatch loss at step 7500: 0.620930
# Minibatch accuracy: 81.2%
# Minibatch loss at step 7550: 0.485198
# Minibatch accuracy: 87.5%
# Minibatch loss at step 7600: 0.606193
# Minibatch accuracy: 75.0%
# Minibatch loss at step 7650: 0.990841
# Minibatch accuracy: 75.0%
# Minibatch loss at step 7700: 1.100055
# Minibatch accuracy: 75.0%
# Minibatch loss at step 7750: 0.991973
# Minibatch accuracy: 62.5%
# Minibatch loss at step 7800: 0.222683
# Minibatch accuracy: 100.0%
# Minibatch loss at step 7850: 0.798160
# Minibatch accuracy: 68.8%
# Minibatch loss at step 7900: 0.222658
# Minibatch accuracy: 93.8%
# Minibatch loss at step 7950: 0.256560
# Minibatch accuracy: 93.8%
# Minibatch loss at step 8000: 1.228078
# Minibatch accuracy: 68.8%
# Minibatch loss at step 8050: 0.405943
# Minibatch accuracy: 87.5%
# Minibatch loss at step 8100: 0.423170
# Minibatch accuracy: 87.5%
# Minibatch loss at step 8150: 1.305925
# Minibatch accuracy: 68.8%
# Minibatch loss at step 8200: 1.018641
# Minibatch accuracy: 81.2%
# Minibatch loss at step 8250: 0.753311
# Minibatch accuracy: 81.2%
# Minibatch loss at step 8300: 0.341006
# Minibatch accuracy: 93.8%
# Minibatch loss at step 8350: 0.792141
# Minibatch accuracy: 68.8%
# Minibatch loss at step 8400: 0.590513
# Minibatch accuracy: 81.2%
# Minibatch loss at step 8450: 0.394933
# Minibatch accuracy: 87.5%
# Minibatch loss at step 8500: 0.286659
# Minibatch accuracy: 87.5%
# Minibatch loss at step 8550: 0.534814
# Minibatch accuracy: 81.2%
# Minibatch loss at step 8600: 0.587875
# Minibatch accuracy: 68.8%
# Minibatch loss at step 8650: 0.808728
# Minibatch accuracy: 75.0%
# Minibatch loss at step 8700: 0.525752
# Minibatch accuracy: 81.2%
# Minibatch loss at step 8750: 0.795662
# Minibatch accuracy: 75.0%
# Minibatch loss at step 8800: 1.030510
# Minibatch accuracy: 68.8%
# Minibatch loss at step 8850: 0.824563
# Minibatch accuracy: 75.0%
# Minibatch loss at step 8900: 0.524647
# Minibatch accuracy: 81.2%
# Minibatch loss at step 8950: 0.821508
# Minibatch accuracy: 68.8%
# Minibatch loss at step 9000: 0.578740
# Minibatch accuracy: 87.5%
# Minibatch loss at step 9050: 0.257221
# Minibatch accuracy: 87.5%
# Minibatch loss at step 9100: 0.335999
# Minibatch accuracy: 93.8%
# Minibatch loss at step 9150: 0.452658
# Minibatch accuracy: 87.5%
# Minibatch loss at step 9200: 0.482292
# Minibatch accuracy: 87.5%
# Minibatch loss at step 9250: 0.065863
# Minibatch accuracy: 93.8%
# Minibatch loss at step 9300: 0.318104
# Minibatch accuracy: 93.8%
# Minibatch loss at step 9350: 1.005031
# Minibatch accuracy: 75.0%
# Minibatch loss at step 9400: 0.371530
# Minibatch accuracy: 87.5%
# Minibatch loss at step 9450: 0.135700
# Minibatch accuracy: 100.0%
# Minibatch loss at step 9500: 1.198651
# Minibatch accuracy: 75.0%
# Minibatch loss at step 9550: 0.234529
# Minibatch accuracy: 93.8%
# Minibatch loss at step 9600: 0.438560
# Minibatch accuracy: 81.2%
# Minibatch loss at step 9650: 0.692283
# Minibatch accuracy: 75.0%
# Minibatch loss at step 9700: 0.971980
# Minibatch accuracy: 68.8%
# Minibatch loss at step 9750: 0.115601
# Minibatch accuracy: 93.8%
# Minibatch loss at step 9800: 0.590862
# Minibatch accuracy: 75.0%
# Minibatch loss at step 9850: 1.125112
# Minibatch accuracy: 68.8%
# Minibatch loss at step 9900: 0.729385
# Minibatch accuracy: 81.2%
# Minibatch loss at step 9950: 0.795810
# Minibatch accuracy: 68.8%
# Minibatch loss at step 10000: 0.619748
# Minibatch accuracy: 75.0%
# Minibatch loss at step 10050: 0.289144
# Minibatch accuracy: 93.8%
# Minibatch loss at step 10100: 0.320137
# Minibatch accuracy: 93.8%
# Minibatch loss at step 10150: 0.636742
# Minibatch accuracy: 81.2%
# Minibatch loss at step 10200: 0.416861
# Minibatch accuracy: 87.5%
# Minibatch loss at step 10250: 0.339064
# Minibatch accuracy: 87.5%
# Minibatch loss at step 10300: 0.831793
# Minibatch accuracy: 81.2%
# Minibatch loss at step 10350: 0.621035
# Minibatch accuracy: 81.2%
# Minibatch loss at step 10400: 0.589121
# Minibatch accuracy: 87.5%
# Minibatch loss at step 10450: 0.490186
# Minibatch accuracy: 81.2%
# Minibatch loss at step 10500: 0.897127
# Minibatch accuracy: 68.8%
# Minibatch loss at step 10550: 0.289926
# Minibatch accuracy: 87.5%
# Minibatch loss at step 10600: 0.517109
# Minibatch accuracy: 81.2%
# Minibatch loss at step 10650: 0.514158
# Minibatch accuracy: 81.2%
# Minibatch loss at step 10700: 1.325789
# Minibatch accuracy: 68.8%
# Minibatch loss at step 10750: 0.957810
# Minibatch accuracy: 75.0%
# Minibatch loss at step 10800: 0.217874
# Minibatch accuracy: 93.8%
# Minibatch loss at step 10850: 0.750505
# Minibatch accuracy: 75.0%
# Minibatch loss at step 10900: 0.288793
# Minibatch accuracy: 87.5%
# Minibatch loss at step 10950: 0.513583
# Minibatch accuracy: 87.5%
# Minibatch loss at step 11000: 0.802903
# Minibatch accuracy: 75.0%
# Minibatch loss at step 11050: 0.422099
# Minibatch accuracy: 81.2%
# Minibatch loss at step 11100: 0.581043
# Minibatch accuracy: 87.5%
# Minibatch loss at step 11150: 0.353640
# Minibatch accuracy: 93.8%
# Minibatch loss at step 11200: 0.868414
# Minibatch accuracy: 81.2%
# Minibatch loss at step 11250: 0.447165
# Minibatch accuracy: 81.2%
# Minibatch loss at step 11300: 1.118942
# Minibatch accuracy: 68.8%
# Minibatch loss at step 11350: 0.226673
# Minibatch accuracy: 93.8%
# Minibatch loss at step 11400: 0.340015
# Minibatch accuracy: 93.8%
# Minibatch loss at step 11450: 0.553121
# Minibatch accuracy: 81.2%
# Minibatch loss at step 11500: 0.371302
# Minibatch accuracy: 93.8%
# Minibatch loss at step 11550: 0.803015
# Minibatch accuracy: 75.0%
# Minibatch loss at step 11600: 0.220840
# Minibatch accuracy: 100.0%
# Minibatch loss at step 11650: 0.559941
# Minibatch accuracy: 87.5%
# Minibatch loss at step 11700: 0.437925
# Minibatch accuracy: 81.2%
# Minibatch loss at step 11750: 0.304634
# Minibatch accuracy: 81.2%
# Minibatch loss at step 11800: 0.159004
# Minibatch accuracy: 100.0%
# Minibatch loss at step 11850: 0.824582
# Minibatch accuracy: 68.8%
# Minibatch loss at step 11900: 0.524754
# Minibatch accuracy: 81.2%
# Minibatch loss at step 11950: 0.631723
# Minibatch accuracy: 81.2%
# Minibatch loss at step 12000: 0.481694
# Minibatch accuracy: 87.5%
# Minibatch loss at step 12050: 0.807693
# Minibatch accuracy: 75.0%
# Minibatch loss at step 12100: 0.254967
# Minibatch accuracy: 93.8%
# Minibatch loss at step 12150: 0.255010
# Minibatch accuracy: 87.5%
# Minibatch loss at step 12200: 0.740482
# Minibatch accuracy: 81.2%
# Minibatch loss at step 12250: 0.466716
# Minibatch accuracy: 81.2%
# Minibatch loss at step 12300: 0.429643
# Minibatch accuracy: 87.5%
# Minibatch loss at step 12350: 0.675059
# Minibatch accuracy: 75.0%
# Minibatch loss at step 12400: 0.813546
# Minibatch accuracy: 75.0%
# Minibatch loss at step 12450: 0.827549
# Minibatch accuracy: 87.5%
# Minibatch loss at step 12500: 0.643258
# Minibatch accuracy: 75.0%
# Minibatch loss at step 12550: 0.591142
# Minibatch accuracy: 75.0%
# Minibatch loss at step 12600: 0.216024
# Minibatch accuracy: 93.8%
# Minibatch loss at step 12650: 0.511794
# Minibatch accuracy: 81.2%
# Minibatch loss at step 12700: 0.854092
# Minibatch accuracy: 68.8%
# Minibatch loss at step 12750: 0.526472
# Minibatch accuracy: 93.8%
# Minibatch loss at step 12800: 0.983461
# Minibatch accuracy: 68.8%
# Minibatch loss at step 12850: 0.744735
# Minibatch accuracy: 75.0%
# Minibatch loss at step 12900: 0.687839
# Minibatch accuracy: 68.8%
# Minibatch loss at step 12950: 0.903536
# Minibatch accuracy: 56.2%
# Minibatch loss at step 13000: 0.523481
# Minibatch accuracy: 81.2%
# Minibatch loss at step 13050: 0.256481
# Minibatch accuracy: 93.8%
# Minibatch loss at step 13100: 0.758519
# Minibatch accuracy: 75.0%
# Minibatch loss at step 13150: 0.568899
# Minibatch accuracy: 93.8%
# Minibatch loss at step 13200: 0.042032
# Minibatch accuracy: 100.0%
# Minibatch loss at step 13250: 1.497740
# Minibatch accuracy: 68.8%
# Minibatch loss at step 13300: 0.204004
# Minibatch accuracy: 93.8%
# Minibatch loss at step 13350: 0.914136
# Minibatch accuracy: 68.8%
# Minibatch loss at step 13400: 0.604637
# Minibatch accuracy: 81.2%
# Minibatch loss at step 13450: 0.211322
# Minibatch accuracy: 93.8%
# Minibatch loss at step 13500: 0.715142
# Minibatch accuracy: 81.2%
# Minibatch loss at step 13550: 0.439647
# Minibatch accuracy: 81.2%
# Minibatch loss at step 13600: 0.536020
# Minibatch accuracy: 81.2%
# Minibatch loss at step 13650: 0.274681
# Minibatch accuracy: 87.5%
# Minibatch loss at step 13700: 0.556576
# Minibatch accuracy: 87.5%
# Minibatch loss at step 13750: 0.330064
# Minibatch accuracy: 93.8%
# Minibatch loss at step 13800: 0.418643
# Minibatch accuracy: 87.5%
# Minibatch loss at step 13850: 1.551365
# Minibatch accuracy: 50.0%
# Minibatch loss at step 13900: 0.321038
# Minibatch accuracy: 93.8%
# Minibatch loss at step 13950: 0.223312
# Minibatch accuracy: 93.8%
# Minibatch loss at step 14000: 1.218434
# Minibatch accuracy: 68.8%
# Minibatch loss at step 14050: 0.389761
# Minibatch accuracy: 87.5%
# Minibatch loss at step 14100: 0.255654
# Minibatch accuracy: 93.8%
# Minibatch loss at step 14150: 0.354848
# Minibatch accuracy: 81.2%
# Minibatch loss at step 14200: 1.028452
# Minibatch accuracy: 75.0%
# Minibatch loss at step 14250: 0.084248
# Minibatch accuracy: 100.0%
# Minibatch loss at step 14300: 0.529368
# Minibatch accuracy: 81.2%
# Minibatch loss at step 14350: 0.414863
# Minibatch accuracy: 81.2%
# Minibatch loss at step 14400: 0.524905
# Minibatch accuracy: 87.5%
# Minibatch loss at step 14450: 0.272209
# Minibatch accuracy: 93.8%
# Minibatch loss at step 14500: 0.406553
# Minibatch accuracy: 87.5%
# Minibatch loss at step 14550: 0.274986
# Minibatch accuracy: 87.5%
# Minibatch loss at step 14600: 0.825480
# Minibatch accuracy: 75.0%
# Minibatch loss at step 14650: 0.804974
# Minibatch accuracy: 68.8%
# Minibatch loss at step 14700: 0.892356
# Minibatch accuracy: 75.0%
# Minibatch loss at step 14750: 0.703639
# Minibatch accuracy: 87.5%
# Minibatch loss at step 14800: 0.430845
# Minibatch accuracy: 81.2%
# Minibatch loss at step 14850: 0.493766
# Minibatch accuracy: 87.5%
# Minibatch loss at step 14900: 0.775802
# Minibatch accuracy: 75.0%
# Minibatch loss at step 14950: 0.322279
# Minibatch accuracy: 93.8%
# Minibatch loss at step 15000: 0.782271
# Minibatch accuracy: 81.2%
# Minibatch loss at step 15050: 0.736780
# Minibatch accuracy: 87.5%
# Minibatch loss at step 15100: 0.431232
# Minibatch accuracy: 81.2%
# Minibatch loss at step 15150: 0.814729
# Minibatch accuracy: 68.8%
# Minibatch loss at step 15200: 0.892950
# Minibatch accuracy: 81.2%
# Minibatch loss at step 15250: 0.280519
# Minibatch accuracy: 87.5%
# Minibatch loss at step 15300: 0.213018
# Minibatch accuracy: 100.0%
# Minibatch loss at step 15350: 0.602022
# Minibatch accuracy: 81.2%
# Minibatch loss at step 15400: 0.413807
# Minibatch accuracy: 87.5%
# Minibatch loss at step 15450: 0.303376
# Minibatch accuracy: 87.5%
# Minibatch loss at step 15500: 0.468396
# Minibatch accuracy: 81.2%
# Minibatch loss at step 15550: 0.449207
# Minibatch accuracy: 87.5%
# Minibatch loss at step 15600: 0.495058
# Minibatch accuracy: 81.2%
# Minibatch loss at step 15650: 0.606148
# Minibatch accuracy: 75.0%
# Minibatch loss at step 15700: 0.426537
# Minibatch accuracy: 93.8%
# Minibatch loss at step 15750: 0.772810
# Minibatch accuracy: 87.5%
# Minibatch loss at step 15800: 0.839297
# Minibatch accuracy: 68.8%
# Minibatch loss at step 15850: 0.545140
# Minibatch accuracy: 75.0%
# Minibatch loss at step 15900: 0.680263
# Minibatch accuracy: 81.2%
# Minibatch loss at step 15950: 0.218445
# Minibatch accuracy: 81.2%
# Minibatch loss at step 16000: 0.372121
# Minibatch accuracy: 87.5%
# Minibatch loss at step 16050: 0.767533
# Minibatch accuracy: 81.2%
# Minibatch loss at step 16100: 0.455550
# Minibatch accuracy: 81.2%
# Minibatch loss at step 16150: 0.330821
# Minibatch accuracy: 87.5%
# Minibatch loss at step 16200: 0.841948
# Minibatch accuracy: 81.2%
# Minibatch loss at step 16250: 0.078479
# Minibatch accuracy: 100.0%
# Minibatch loss at step 16300: 0.472196
# Minibatch accuracy: 87.5%
# Minibatch loss at step 16350: 0.332393
# Minibatch accuracy: 87.5%
# Minibatch loss at step 16400: 0.312052
# Minibatch accuracy: 81.2%
# Minibatch loss at step 16450: 0.069369
# Minibatch accuracy: 100.0%
# Minibatch loss at step 16500: 0.434382
# Minibatch accuracy: 81.2%
# Minibatch loss at step 16550: 0.128072
# Minibatch accuracy: 93.8%
# Minibatch loss at step 16600: 0.785065
# Minibatch accuracy: 75.0%
# Minibatch loss at step 16650: 0.725821
# Minibatch accuracy: 87.5%
# Minibatch loss at step 16700: 0.389438
# Minibatch accuracy: 87.5%
# Minibatch loss at step 16750: 0.377709
# Minibatch accuracy: 87.5%
# Minibatch loss at step 16800: 0.633261
# Minibatch accuracy: 81.2%
# Minibatch loss at step 16850: 0.068902
# Minibatch accuracy: 100.0%
# Minibatch loss at step 16900: 0.353709
# Minibatch accuracy: 87.5%
# Minibatch loss at step 16950: 0.212432
# Minibatch accuracy: 93.8%
# Minibatch loss at step 17000: 0.456237
# Minibatch accuracy: 87.5%
# Minibatch loss at step 17050: 0.343455
# Minibatch accuracy: 87.5%
# Minibatch loss at step 17100: 0.258333
# Minibatch accuracy: 93.8%
# Minibatch loss at step 17150: 0.231122
# Minibatch accuracy: 93.8%
# Minibatch loss at step 17200: 0.420042
# Minibatch accuracy: 87.5%
# Minibatch loss at step 17250: 0.509463
# Minibatch accuracy: 87.5%
# Minibatch loss at step 17300: 0.309657
# Minibatch accuracy: 93.8%
# Minibatch loss at step 17350: 0.469297
# Minibatch accuracy: 87.5%
# Minibatch loss at step 17400: 0.662913
# Minibatch accuracy: 81.2%
# Minibatch loss at step 17450: 0.458313
# Minibatch accuracy: 87.5%
# Minibatch loss at step 17500: 0.381442
# Minibatch accuracy: 81.2%
# Minibatch loss at step 17550: 0.388783
# Minibatch accuracy: 81.2%
# Minibatch loss at step 17600: 0.881331
# Minibatch accuracy: 68.8%
# Minibatch loss at step 17650: 0.507502
# Minibatch accuracy: 87.5%
# Minibatch loss at step 17700: 0.532573
# Minibatch accuracy: 81.2%
# Minibatch loss at step 17750: 0.334378
# Minibatch accuracy: 93.8%
# Minibatch loss at step 17800: 0.193262
# Minibatch accuracy: 93.8%
# Minibatch loss at step 17850: 0.091650
# Minibatch accuracy: 100.0%
# Minibatch loss at step 17900: 0.237204
# Minibatch accuracy: 93.8%
# Minibatch loss at step 17950: 0.284805
# Minibatch accuracy: 87.5%
# Minibatch loss at step 18000: 0.265997
# Minibatch accuracy: 93.8%
# Minibatch loss at step 18050: 0.303433
# Minibatch accuracy: 87.5%
# Minibatch loss at step 18100: 0.635556
# Minibatch accuracy: 81.2%
# Minibatch loss at step 18150: 0.791157
# Minibatch accuracy: 81.2%
# Minibatch loss at step 18200: 0.218856
# Minibatch accuracy: 93.8%
# Minibatch loss at step 18250: 0.006600
# Minibatch accuracy: 100.0%
# Minibatch loss at step 18300: 0.664124
# Minibatch accuracy: 81.2%
# Minibatch loss at step 18350: 0.955563
# Minibatch accuracy: 68.8%
# Minibatch loss at step 18400: 0.468074
# Minibatch accuracy: 87.5%
# Minibatch loss at step 18450: 0.684176
# Minibatch accuracy: 75.0%
# Minibatch loss at step 18500: 0.431636
# Minibatch accuracy: 81.2%
# Minibatch loss at step 18550: 0.124196
# Minibatch accuracy: 93.8%
# Minibatch loss at step 18600: 0.744509
# Minibatch accuracy: 81.2%
# Minibatch loss at step 18650: 0.547801
# Minibatch accuracy: 75.0%
# Minibatch loss at step 18700: 0.265730
# Minibatch accuracy: 93.8%
# Minibatch loss at step 18750: 0.264026
# Minibatch accuracy: 87.5%
# Minibatch loss at step 18800: 0.128830
# Minibatch accuracy: 100.0%
# Minibatch loss at step 18850: 0.336053
# Minibatch accuracy: 87.5%
# Minibatch loss at step 18900: 0.430362
# Minibatch accuracy: 81.2%
# Minibatch loss at step 18950: 0.650970
# Minibatch accuracy: 87.5%
# Minibatch loss at step 19000: 0.205653
# Minibatch accuracy: 100.0%
# Minibatch loss at step 19050: 0.408733
# Minibatch accuracy: 87.5%
# Minibatch loss at step 19100: 0.320017
# Minibatch accuracy: 93.8%
# Minibatch loss at step 19150: 0.710142
# Minibatch accuracy: 81.2%
# Minibatch loss at step 19200: 0.755698
# Minibatch accuracy: 75.0%
# Minibatch loss at step 19250: 0.053061
# Minibatch accuracy: 100.0%
# Minibatch loss at step 19300: 0.296963
# Minibatch accuracy: 93.8%
# Minibatch loss at step 19350: 0.123619
# Minibatch accuracy: 100.0%
# Minibatch loss at step 19400: 0.234892
# Minibatch accuracy: 87.5%
# Minibatch loss at step 19450: 1.022528
# Minibatch accuracy: 68.8%
# Minibatch loss at step 19500: 0.327940
# Minibatch accuracy: 81.2%
# Minibatch loss at step 19550: 0.332659
# Minibatch accuracy: 93.8%
# Minibatch loss at step 19600: 0.275607
# Minibatch accuracy: 93.8%
# Minibatch loss at step 19650: 0.300744
# Minibatch accuracy: 93.8%
# Minibatch loss at step 19700: 0.369276
# Minibatch accuracy: 87.5%
# Minibatch loss at step 19750: 1.242403
# Minibatch accuracy: 68.8%
# Minibatch loss at step 19800: 0.795265
# Minibatch accuracy: 87.5%
# Minibatch loss at step 19850: 0.257094
# Minibatch accuracy: 93.8%
# Minibatch loss at step 19900: 0.212704
# Minibatch accuracy: 93.8%
# Minibatch loss at step 19950: 0.624089
# Minibatch accuracy: 81.2%
# Minibatch loss at step 20000: 0.170222
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.7%
# Test accuracy: 93.4%
